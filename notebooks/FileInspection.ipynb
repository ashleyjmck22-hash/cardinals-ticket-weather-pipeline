# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\ashle\Downloads\DBA Project - Data Set.xlsx")
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   snapshot_date        992 non-null    datetime64[ns]
#  1   game_date            992 non-null    datetime64[ns]
#  2   unique_tickets_sold  992 non-null    int64
#  3   unique_page_clicks   992 non-null    int64
# dtypes: datetime64[ns](2), int64(2)
# memory usage: 31.1 KB
#                        snapshot_date                      game_date  \
# count                            992                            992
# mean   2026-03-26 04:16:56.129032448  2026-04-20 08:33:52.258064640
# min              2026-03-01 00:00:00            2026-03-26 00:00:00
# 25%              2026-03-12 00:00:00            2026-04-11 00:00:00
# 50%              2026-03-24 00:00:00            2026-04-25 00:00:00
# 75%              2026-04-07 00:00:00            2026-05-03 00:00:00
# ...

# %%
df.columns
df.shape
# Out:
# (992, 4)

# %%
df["days_before_game"] = (df["game_date"] - df["snapshot_date"]).dt.days # Tells us how many days before the game the snapshot start  

df.head(10)
# Out:
#   snapshot_date  game_date  unique_tickets_sold  unique_page_clicks  \
# 0    2026-03-01 2026-03-26                   21                 181
# 1    2026-03-01 2026-03-28                    3                 254
# 2    2026-03-01 2026-03-29                    2                 217
# 3    2026-03-01 2026-03-30                    3                 194
# 4    2026-03-01 2026-03-31                    2                 145
# 5    2026-03-01 2026-04-01                    5                 137
# 6    2026-03-01 2026-04-10                    1                 130
# 7    2026-03-01 2026-04-11                    2                 219
# 8    2026-03-01 2026-04-12                    7                 193
# 9    2026-03-01 2026-04-13                    2                 141
#
#    days_before_game
# 0                25
# 1                27
# 2                28
# 3                29
# 4                30
# 5                31
# 6                40
# 7                41
# 8                42
# ...

# %%
df["days_before_game"].describe() # How long the observation window is
# Out:
# count    992.000000
# mean      25.178427
# std       16.685051
# min        0.000000
# 25%       11.000000
# 50%       23.000000
# 75%       37.000000
# max       66.000000
# Name: days_before_game, dtype: float64

# %%
# This tells us very important information about the data structure. 
# A snapshot of ticket activity for a future game on a given day.
# example: On March 1, observe interest for games that happen 25-43 days later 
# This is important because the weather forecast changes over time and the pipeline needs to capture the forecast as it existed on each snapshot_date.

# %%
# The business question depends on how forecasts evolve over time leading up to a game, so the data model must preserve both the game date and the observation date (snapshot_date).

# %%
df["game_date"].nunique() # how many unique games exist 
df["snapshot_date"].nunique()
# Out:
# 67

# %%
# 67 unique game_date values, one row per (snapshot_date, game_date)

# %%
# What we know 
# 1)  67 games 
# 2) up to 66 days of lead time 
# 3) Weather matters 0-10 days before game 
# Note: Because weather forecasts are most reliable within about 7–10 days of an event, the pipeline attaches forecast features only within that window to avoid misleading long-range forecasts.

# %%
df["days_before_game"].value_counts().sort_index().head(20)
# Out:
# days_before_game
# 0     21
# 1     21
# 2     21
# 3     21
# 4     21
# 5     21
# 6     21
# 7     21
# 8     21
# 9     21
# 10    21
# 11    21
# 12    21
# 13    21
# 14    21
# 15    21
# 16    21
# 17    21
# 18    21
# 19    21
# Name: count, dtype: int64

# %%
# The dataset contains ticket engagement snapshots up to about 21 days before each game. Since weather forecasts are most reliable within roughly a 7–14 day window, the pipeline attaches forecast features when the game falls within that window, ensuring the analysis reflects realistic forecasting conditions.
